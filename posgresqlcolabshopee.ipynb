# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome(r'D:\UltimatePython\chromedriver-win64\chromedriver.exe')
driver.get('https://shopee.co.th/')
thai_button = driver.find_element_by_class_name("shopee-button-outline")
thai_button.click()
close_button = driver.execute_script('return document.querySelector("shopee-banner-popup-stateful").shadowRoot.querySelector("div.shopee-popup__close-btn")')
close_button.click()
search_bar = driver.find_element_by_class_name("shopee-searchbar-input__input")
search_bar.send_keys("ไมโครเวฟ")
search_bar.send_keys(Keys.ENTER)
time.sleep(3)
Id_name = driver.find_element_by_name("loginKey")
Id_name.send_keys("chopper_tnt")
password = driver.find_element_by_name("password")
password.send_keys("Chaninat1160")
time.sleep(3)
login = driver.find_element_by_class_name("wyhvVD")
login.click()
driver.execute_script('document.body.style.zoom="10%"')

# %%
all_product = driver.find_elements_by_class_name("whIxGK")
len(all_product)
# Out:
# 60

# %%
y = []
for x in all_product:
    data_dict = dict()
    name = x.find_element_by_class_name("Cve6sh").text
    try:
        price = x.find_element_by_class_name("rVLWG6").text
    except:
        price = None
    try:
        Amount = x.find_element_by_class_name("uEPGHT").text
    except:
        Amount = None

    data_dict["name"] = name
    data_dict['Price'] = price
    data_dict['Amount'] = Amount
    y.append(data_dict)

# %%
import pandas as pd
df = pd.DataFrame(y)
df
# Out:
#                                                  name            Price  \
# 0   กล่องอุ่นอาหารในไมโครเวฟ กล่องนึ่ง ชามนึ่งอาหา...              ฿59
# 1   Simplus Airfryer หม้อทอดไร้น้ำมันอเนกประสงค์ ค...      ฿889 - ฿899
# 2   3/4/5ชั้น ชั้นวางของพับเก็บได้ ชั้นวางของวางไม...             ฿788
# 3   EllaMall ชั้นวางบนไมโครเวฟ ปรับขนาดได้ ชั้นวาง...      ฿289 - ฿509
# 4   เตาอบ 25 ลิตร เตาอบไฟฟ้า ท่อล่างและท่อบนทำความ...      ฿409 - ฿719
# 5   HAIER ไมโครเวฟ 20 ลิตร รุ่น HMW-M2001W [HME] ส...           ฿1,350
# 6   [Pre-order] TOSHIBA เตาอบไมโครเวฟขนาด 20 ลิตร ...           ฿1,790
# 7   HAIER ไมโครเวฟ รุ่น HMW-M2002S สีเงิน / M2001W...           ฿1,349
# 8   [ใส่โค้ด D6PBAN9E รับ 300 coins] Electrolux ไม...  ฿2,068 - ฿2,168
# 9   SAMSUNG ไมโครเวฟ SOLO 700 วัตต์ 20 ลิตร สีดำ ร...           ฿1,690
# 10            SHARP ไมโครเวฟ รุ่น R-2200F-S (20 ลิตร)           ฿1,929
# 11  [ จัดส่งฟรี ] SAMSUNG MICROWAVE ไมโครเวฟ อุ่นอ...           ฿2,790
# ...

# %%
part = "https://shopee.co.th/search?is_from_login=true&keyword=%E0%B9%84%E0%B8%A1%E0%B9%82%E0%B8%84%E0%B8%A3%E0%B9%80%E0%B8%A7%E0%B8%9F&page="
page = 5
data_dict_list = []
while page < 10 :
    url = part+str(page)
    driver.get(url)
    driver.execute_script('document.body.style.zoom="10%"')
    time.sleep(5)
    all_product = driver.find_elements_by_class_name("whIxGK")
    for product in all_product:
        data_dict = dict()
        name = product.find_element_by_class_name("Cve6sh").text
        try:
            price = product.find_element_by_class_name("rVLWG6").text
        except:
            price = None
        try:
            Amount = product.find_element_by_class_name("uEPGHT").text
        except:
            Amount = None

        data_dict["name"] = name
        data_dict['Price'] = price
        data_dict['Amount'] = Amount
        data_dict_list.append(data_dict)
    page = page+1
    print("Complete page number",page)
# Out:
# Complete page number 6
# Complete page number 7
# Complete page number 8
# Complete page number 9
# Complete page number 10

# %%
df = pd.DataFrame(data_dict_list)
df
# Out:
#                                                   name          Price  \
# 0    สแตนเลส316 อย่างหนา📍TFMXR ชั้นวางเตาแก๊สสแตนเล...  ฿935 - ฿2,139
# 1    Xiaomi Mijia Electric Induction Cooker เตาแม่เ...  ฿499 - ฿1,422
# 2    INSSA Air Fryer Gen-S Series หม้อทอดไร้น้ำมัน ...  ฿929 - ฿1,199
# 3    750ml/1000ml 2ช่อง(300ชิ้น/ลัง)2Fสีใส สีดำ กล่...    ฿750 - ฿830
# 4      ELECTROLUX ไมโครเวฟ 20 ลิตร รุ่น EMG20K22B |MC|         ฿3,290
# ..                                                 ...            ...
# 295  Be> แม่พิมพ์ขนมไหว้พระจันทร์แม่พิมพ์เทศกาลความ...            ฿89
# 296  จานไมโครเวฟแอลจีขนาด24.5cm.(จานมีตำหนิขอคนรับไ...           ฿159
# 297  แมกนีตรอน ไมโครเวฟ TOSHIBA โตชิบา รุ่น 2M253J ...           ฿300
# 298        หม้อแปลงไมโครเวฟ Samsung 800w.มือสองของเเท้           ฿330
# 299  ขารองจานไมโคเวฟ(ขากลมเทียบใช้ได้ทั่วไปขนาด17.5...            ฿95
#
#                   Amount
# 0        ขายแล้ว 11 ชิ้น
# 1    ขายแล้ว 2.7พัน ชิ้น
# 2         ขายแล้ว 4 ชิ้น
# ...

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
con = psycopg2.connect(
    host='localhost',
    database = 'Shopee',
    user = 'postgres',
    password = 'chaninat1160')
print(con)
# Out:
# <connection object at 0x00000277129A0F20; dsn: 'user=postgres password=xxx dbname=Shopee host=localhost', closed: 0>

# %%
user = 'postgres'
password = 'chaninat1160'
database = 'Shopee'
host = 'localhost'
port = 5432
con = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
print(con)
# Out:
# Engine(postgresql://postgres:***@localhost:5432/Shopee)

# %%
df.to_sql('Shopee_microwave',con,if_exists='replace',index=False)
# Out:
# 300

# %%
sql = '''SELECT * FROM public."Shopee_microwave"'''
df1 = pd.read_sql(sql,con)
df1
# Out:
# C:\Users\chopp\AppData\Local\Temp\ipykernel_18428\534486221.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql(sql,con)
#                                                   name          Price  \
# 0    กล่องอุ่นอาหารในไมโครเวฟ กล่องนึ่ง ชามนึ่งอาหา...            ฿59
# 1    Simplus Airfryer หม้อทอดไร้น้ำมันอเนกประสงค์ ค...    ฿889 - ฿899
# 2    3/4/5ชั้น ชั้นวางของพับเก็บได้ ชั้นวางของวางไม...           ฿788
# 3    EllaMall ชั้นวางบนไมโครเวฟ ปรับขนาดได้ ชั้นวาง...    ฿289 - ฿509
# 4    เตาอบ 25 ลิตร เตาอบไฟฟ้า ท่อล่างและท่อบนทำความ...    ฿409 - ฿719
# ..                                                 ...            ...
# 295  Philips หม้อหุงข้าวไฟฟ้า 3 ลิตร สีขาว หม้อหุงข...         ฿1,288
# 296  Xiaomi Mijia Electric Induction Cooker เตาแม่เ...  ฿499 - ฿1,422
# ...

# %%
table = pd.concat([df,df1],axis=0)
table
# Out:
#                                                   name          Price  \
# 0    สแตนเลส316 อย่างหนา📍TFMXR ชั้นวางเตาแก๊สสแตนเล...  ฿935 - ฿2,139
# 1    Xiaomi Mijia Electric Induction Cooker เตาแม่เ...  ฿499 - ฿1,422
# 2    INSSA Air Fryer Gen-S Series หม้อทอดไร้น้ำมัน ...  ฿929 - ฿1,199
# 3    750ml/1000ml 2ช่อง(300ชิ้น/ลัง)2Fสีใส สีดำ กล่...    ฿750 - ฿830
# 4      ELECTROLUX ไมโครเวฟ 20 ลิตร รุ่น EMG20K22B |MC|         ฿3,290
# ..                                                 ...            ...
# 295  Philips หม้อหุงข้าวไฟฟ้า 3 ลิตร สีขาว หม้อหุงข...         ฿1,288
# 296  Xiaomi Mijia Electric Induction Cooker เตาแม่เ...  ฿499 - ฿1,422
# 297  สแตนเลส316 อย่างหนา📍TFMXR ชั้นวางเตาแก๊สสแตนเล...  ฿935 - ฿2,139
# 298  750ml/1000ml 2ช่อง(300ชิ้น/ลัง)2Fสีใส สีดำ กล่...    ฿750 - ฿830
# 299  INSSA Air Fryer Gen-S Series หม้อทอดไร้น้ำมัน ...  ฿929 - ฿1,199
#
#                   Amount
# 0        ขายแล้ว 11 ชิ้น
# 1    ขายแล้ว 2.7พัน ชิ้น
# 2         ขายแล้ว 4 ชิ้น
# ...

# %%
table = table.reset_index(drop='True')
table
# Out:
#                                                   name          Price  \
# 0    สแตนเลส316 อย่างหนา📍TFMXR ชั้นวางเตาแก๊สสแตนเล...  ฿935 - ฿2,139
# 1    Xiaomi Mijia Electric Induction Cooker เตาแม่เ...  ฿499 - ฿1,422
# 2    INSSA Air Fryer Gen-S Series หม้อทอดไร้น้ำมัน ...  ฿929 - ฿1,199
# 3    750ml/1000ml 2ช่อง(300ชิ้น/ลัง)2Fสีใส สีดำ กล่...    ฿750 - ฿830
# 4      ELECTROLUX ไมโครเวฟ 20 ลิตร รุ่น EMG20K22B |MC|         ฿3,290
# ..                                                 ...            ...
# 595  Philips หม้อหุงข้าวไฟฟ้า 3 ลิตร สีขาว หม้อหุงข...         ฿1,288
# 596  Xiaomi Mijia Electric Induction Cooker เตาแม่เ...  ฿499 - ฿1,422
# 597  สแตนเลส316 อย่างหนา📍TFMXR ชั้นวางเตาแก๊สสแตนเล...  ฿935 - ฿2,139
# 598  750ml/1000ml 2ช่อง(300ชิ้น/ลัง)2Fสีใส สีดำ กล่...    ฿750 - ฿830
# 599  INSSA Air Fryer Gen-S Series หม้อทอดไร้น้ำมัน ...  ฿929 - ฿1,199
#
#                   Amount
# 0        ขายแล้ว 11 ชิ้น
# 1    ขายแล้ว 2.7พัน ชิ้น
# 2         ขายแล้ว 4 ชิ้น
# ...

# %%
table.to_sql('Shopee_microwave',con,if_exists='replace',index=False)
# Out:
# 600
