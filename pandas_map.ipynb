# %%
import pandas as pd

# %%
dat = pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')

# %%
df = dat.sample(10).reset_index(drop=True) #เริ่มนับใหม่
df
# Out:
#   manufacturer                   model  displ  year  cyl       trans drv  cty  \
# 0       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4   15
# 1       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4   13
# 2      hyundai                  sonata    2.4  1999    4    auto(l4)   f   18
# 3        dodge             caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 4         ford                 mustang    3.8  1999    6  manual(m5)   r   18
# 5   volkswagen              new beetle    2.0  1999    4    auto(l4)   f   19
# 6         audi                      a4    2.8  1999    6    auto(l5)   f   16
# 7         audi              a4 quattro    3.1  2008    6  manual(m6)   4   15
# 8        dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 9   volkswagen              new beetle    1.9  1999    4    auto(l4)   f   29
#
#    hwy fl       class
# 0   20  r      pickup
# 1   18  r         suv
# 2   26  r     midsize
# ...

# %%
df.manufacturer.str.capitalize()
# Out:
# 0        Toyota
# 1        Toyota
# 2       Hyundai
# 3         Dodge
# 4          Ford
# 5    Volkswagen
# 6          Audi
# 7          Audi
# 8         Dodge
# 9    Volkswagen
# Name: manufacturer, dtype: object

# %%
df['trans_am'] = df.trans.map(lambda v:'Auto' if v[0]=='a' else 'Manual').astype('category')
df
# Out:
#   manufacturer                   model  displ  year  cyl       trans drv  cty  \
# 0       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4   15
# 1       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4   13
# 2      hyundai                  sonata    2.4  1999    4    auto(l4)   f   18
# 3        dodge             caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 4         ford                 mustang    3.8  1999    6  manual(m5)   r   18
# 5   volkswagen              new beetle    2.0  1999    4    auto(l4)   f   19
# 6         audi                      a4    2.8  1999    6    auto(l5)   f   16
# 7         audi              a4 quattro    3.1  2008    6  manual(m6)   4   15
# 8        dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 9   volkswagen              new beetle    1.9  1999    4    auto(l4)   f   29
#
#    hwy fl       class trans_am
# 0   20  r      pickup   Manual
# 1   18  r         suv     Auto
# ...

# %%
def am(v):
    if v[0]=='a':
        return 'Auto'
    else:
        return 'Mannual'

# %%
df.trans.map(am)
# Out:
# 0    Mannual
# 1       Auto
# 2       Auto
# 3       Auto
# 4    Mannual
# 5       Auto
# 6       Auto
# 7    Mannual
# 8       Auto
# 9       Auto
# Name: trans, dtype: object

# %%
df['drv2'] = df.drv.map({'f':'Front','r':'Rear','4':'4-wheel'}).astype('category')

# %%
df
# Out:
#   manufacturer                   model  displ  year  cyl       trans drv  cty  \
# 0       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4   15
# 1       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4   13
# 2      hyundai                  sonata    2.4  1999    4    auto(l4)   f   18
# 3        dodge             caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 4         ford                 mustang    3.8  1999    6  manual(m5)   r   18
# 5   volkswagen              new beetle    2.0  1999    4    auto(l4)   f   19
# 6         audi                      a4    2.8  1999    6    auto(l5)   f   16
# 7         audi              a4 quattro    3.1  2008    6  manual(m6)   4   15
# 8        dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 9   volkswagen              new beetle    1.9  1999    4    auto(l4)   f   29
#
#    hwy fl       class trans_am     drv2
# 0   20  r      pickup   Manual  4-wheel
# ...

# %%
df = pd.read_table('https://github.com/prasertcbs/tutorial/raw/master/currency.tsv',index_col='Year')
df
# Out:
#               TV      Camera       Phone
# Year
# 2011  THB556,300  THB943,620  THB518,600
# 2012  THB344,200  THB583,370  THB323,920
# 2013  THB727,320  THB548,640  THB941,500
# 2014  THB462,870  THB661,520  THB650,570
# 2015  THB916,600  THB974,180  THB148,740
# 2016  THB176,830  THB588,990  THB910,570
# 2017  THB745,550  THB896,860  THB982,820

# %%
df.TV.str.replace('\D','').astype('int')
# Out:
# C:\Users\chopp\AppData\Local\Temp\ipykernel_5104\141471785.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.TV.str.replace('\D','').astype('int')
# Year
# 2011    556300
# 2012    344200
# 2013    727320
# 2014    462870
# 2015    916600
# 2016    176830
# 2017    745550
# Name: TV, dtype: int32

# %%
import re
def remove_nondigit(v):
    return int(re.sub(r'\D','',v))

# %%
remove_nondigit('THB123456')
# Out:
# 123456

# %%
df2 = df.applymap(lambda v:int(re.sub(r'\D','',v)))
df2
# Out:
#           TV  Camera   Phone
# Year
# 2011  556300  943620  518600
# 2012  344200  583370  323920
# 2013  727320  548640  941500
# 2014  462870  661520  650570
# 2015  916600  974180  148740
# 2016  176830  588990  910570
# 2017  745550  896860  982820

# %%
df2 = df.applymap(remove_nondigit) #ใช้ applymap ได้
df2
# Out:
#           TV  Camera   Phone
# Year
# 2011  556300  943620  518600
# 2012  344200  583370  323920
# 2013  727320  548640  941500
# 2014  462870  661520  650570
# 2015  916600  974180  148740
# 2016  176830  588990  910570
# 2017  745550  896860  982820

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
dat
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
dat[['manufacturer','model','class']].applymap(str.capitalize)
# Out:
#     manufacturer   model    class
# 0           Audi      A4  Compact
# 1           Audi      A4  Compact
# 2           Audi      A4  Compact
# 3           Audi      A4  Compact
# 4           Audi      A4  Compact
# ..           ...     ...      ...
# 229   Volkswagen  Passat  Midsize
# 230   Volkswagen  Passat  Midsize
# 231   Volkswagen  Passat  Midsize
# 232   Volkswagen  Passat  Midsize
# 233   Volkswagen  Passat  Midsize
#
# [234 rows x 3 columns]

# %%
dat[['manufacturer','model','class']] = dat[['manufacturer','model','class']].applymap(str.capitalize)
dat
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           Audi      A4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           Audi      A4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           Audi      A4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           Audi      A4    2.0  2008    4    auto(av)   f   21   30  p
# 4           Audi      A4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   Volkswagen  Passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   Volkswagen  Passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   Volkswagen  Passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   Volkswagen  Passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   Volkswagen  Passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    Compact
# 1    Compact
# 2    Compact
# 3    Compact
# 4    Compact
# ..       ...
# ...

# %%
dat[['trans']]=dat[['trans']].applymap(str.capitalize)
dat
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           Audi      A4    1.8  1999    4    Auto(l5)   f   18   29  p
# 1           Audi      A4    1.8  1999    4  Manual(m5)   f   21   29  p
# 2           Audi      A4    2.0  2008    4  Manual(m6)   f   20   31  p
# 3           Audi      A4    2.0  2008    4    Auto(av)   f   21   30  p
# 4           Audi      A4    2.8  1999    6    Auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   Volkswagen  Passat    2.0  2008    4    Auto(s6)   f   19   28  p
# 230   Volkswagen  Passat    2.0  2008    4  Manual(m6)   f   21   29  p
# 231   Volkswagen  Passat    2.8  1999    6    Auto(l5)   f   16   26  p
# 232   Volkswagen  Passat    2.8  1999    6  Manual(m5)   f   18   26  p
# 233   Volkswagen  Passat    3.6  2008    6    Auto(s6)   f   17   26  p
#
#        class
# 0    Compact
# 1    Compact
# 2    Compact
# 3    Compact
# 4    Compact
# ..       ...
# ...

# %%
dat[['trans']].applymap(str.capitalize)
# Out:
#           trans
# 0      Auto(l5)
# 1    Manual(m5)
# 2    Manual(m6)
# 3      Auto(av)
# 4      Auto(l5)
# ..          ...
# 229    Auto(s6)
# 230  Manual(m6)
# 231    Auto(l5)
# 232  Manual(m5)
# 233    Auto(s6)
#
# [234 rows x 1 columns]

# %%
dat[~dat.manufacturer.isin(['Toyota','Nissan','Honda'])]
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           Audi      A4    1.8  1999    4    Auto(l5)   f   18   29  p
# 1           Audi      A4    1.8  1999    4  Manual(m5)   f   21   29  p
# 2           Audi      A4    2.0  2008    4  Manual(m6)   f   20   31  p
# 3           Audi      A4    2.0  2008    4    Auto(av)   f   21   30  p
# 4           Audi      A4    2.8  1999    6    Auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   Volkswagen  Passat    2.0  2008    4    Auto(s6)   f   19   28  p
# 230   Volkswagen  Passat    2.0  2008    4  Manual(m6)   f   21   29  p
# 231   Volkswagen  Passat    2.8  1999    6    Auto(l5)   f   16   26  p
# 232   Volkswagen  Passat    2.8  1999    6  Manual(m5)   f   18   26  p
# 233   Volkswagen  Passat    3.6  2008    6    Auto(s6)   f   17   26  p
#
#        class
# 0    Compact
# 1    Compact
# 2    Compact
# 3    Compact
# 4    Compact
# ..       ...
# ...

# %%
dat[dat.manufacturer.str.contains('toyota|Nissan|honda',case=False)]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 99         Honda                   Civic    1.6  1999    4  Manual(m5)   f
# 100        Honda                   Civic    1.6  1999    4    Auto(l4)   f
# 101        Honda                   Civic    1.6  1999    4  Manual(m5)   f
# 102        Honda                   Civic    1.6  1999    4  Manual(m5)   f
# 103        Honda                   Civic    1.6  1999    4    Auto(l4)   f
# 104        Honda                   Civic    1.8  2008    4  Manual(m5)   f
# 105        Honda                   Civic    1.8  2008    4    Auto(l5)   f
# 106        Honda                   Civic    1.8  2008    4    Auto(l5)   f
# 107        Honda                   Civic    2.0  2008    4  Manual(m6)   f
# 141       Nissan                  Altima    2.4  1999    4  Manual(m5)   f
# 142       Nissan                  Altima    2.4  1999    4    Auto(l4)   f
# ...

# %%
dat[dat.manufacturer.str.match('toyota|Nissan|honda',case=False)]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 99         Honda                   Civic    1.6  1999    4  Manual(m5)   f
# 100        Honda                   Civic    1.6  1999    4    Auto(l4)   f
# 101        Honda                   Civic    1.6  1999    4  Manual(m5)   f
# 102        Honda                   Civic    1.6  1999    4  Manual(m5)   f
# 103        Honda                   Civic    1.6  1999    4    Auto(l4)   f
# 104        Honda                   Civic    1.8  2008    4  Manual(m5)   f
# 105        Honda                   Civic    1.8  2008    4    Auto(l5)   f
# 106        Honda                   Civic    1.8  2008    4    Auto(l5)   f
# 107        Honda                   Civic    2.0  2008    4  Manual(m6)   f
# 141       Nissan                  Altima    2.4  1999    4  Manual(m5)   f
# 142       Nissan                  Altima    2.4  1999    4    Auto(l4)   f
# ...

# %%
dat[dat.manufacturer.str.match('^T.*a$')]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 173       Toyota             4runner 4wd    2.7  1999    4  Manual(m5)   4
# 174       Toyota             4runner 4wd    2.7  1999    4    Auto(l4)   4
# 175       Toyota             4runner 4wd    3.4  1999    6    Auto(l4)   4
# 176       Toyota             4runner 4wd    3.4  1999    6  Manual(m5)   4
# 177       Toyota             4runner 4wd    4.0  2008    6    Auto(l5)   4
# 178       Toyota             4runner 4wd    4.7  2008    8    Auto(l5)   4
# 179       Toyota                   Camry    2.2  1999    4  Manual(m5)   f
# 180       Toyota                   Camry    2.2  1999    4    Auto(l4)   f
# 181       Toyota                   Camry    2.4  2008    4  Manual(m5)   f
# 182       Toyota                   Camry    2.4  2008    4    Auto(l5)   f
# 183       Toyota                   Camry    3.0  1999    6    Auto(l4)   f
# ...
