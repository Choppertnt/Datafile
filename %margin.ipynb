# %%
from statistics import *
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r'D:\Future Skill\Data analytics\WorkshopData Aanlytic\Workshop\data.csv')

# %%
data
# Out:
#          Unnamed: 0                             Region           Country  \
# 0                 0                 Sub-Saharan Africa      South Africa
# 1                 1                 Sub-Saharan Africa      South Africa
# 2                 2       Middle East and North Africa           Morocco
# 3                 3       Middle East and North Africa           Morocco
# 4                 4              Australia and Oceania  Papua New Guinea
# ...             ...                                ...               ...
# 1500009     1500009                               Asia             India
# 1500010     1500010              Australia and Oceania               NaN
# 1500011     1500011  Central America and the Caribbean               NaN
# 1500012     1500012                               Asia            Brunei
# 1500013     1500013       Middle East and North Africa            Israel
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
data.drop(columns='Unnamed: 0',inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500014 entries, 0 to 1500013
# Data columns (total 14 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Region          1500012 non-null  object
#  1   Country         1500008 non-null  object
#  2   Item Type       1500013 non-null  object
#  3   Sales Channel   1500013 non-null  object
#  4   Order Priority  1500014 non-null  object
#  5   Order Date      1500014 non-null  object
#  6   Order ID        1500014 non-null  int64
#  7   Ship Date       1500014 non-null  object
#  8   Units Sold      1500014 non-null  int64
#  9   Unit Price      1500014 non-null  float64
#  10  Unit Cost       1500014 non-null  float64
#  11  Total Revenue   1500009 non-null  float64
#  12  Total Cost      1500009 non-null  float64
#  13  Total Profit    1500009 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 160.2+ MB

# %%
data = data[data['Country'].notnull()]

# %%
data['%margin'] = ((data['Total Profit'] / data['Total Revenue'])*100).round(2)
# Out:
# C:\Users\chopp\AppData\Local\Temp\ipykernel_3320\2539237771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['%margin'] = ((data['Total Profit'] / data['Total Revenue'])*100).round(2)

# %%
data
# Out:
#                                Region           Country        Item Type  \
# 0                  Sub-Saharan Africa      South Africa           Fruits
# 1                  Sub-Saharan Africa      South Africa           Fruits
# 2        Middle East and North Africa           Morocco          Clothes
# 3        Middle East and North Africa           Morocco          Clothes
# 4               Australia and Oceania  Papua New Guinea             Meat
# ...                               ...               ...              ...
# 1500006            Sub-Saharan Africa          Zimbabwe  Office Supplies
# 1500008         Australia and Oceania           Vanuatu           Fruits
# 1500009                          Asia             India           Snacks
# 1500012                          Asia            Brunei           Cereal
# 1500013  Middle East and North Africa            Israel        Beverages
#
#         Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
data.loc[data['Total Profit'].idxmax()]
# Out:
# Region               Europe
# Country             Romania
# Item Type         Cosmetics
# Sales Channel        Online
# Order Priority            M
# Order Date        3/16/2016
# Order ID          707318103
# Ship Date          5/3/2016
# Units Sold            10000
# Unit Price            437.2
# Unit Cost            263.33
# Total Revenue     4372000.0
# Total Cost        2633300.0
# Total Profit      1738700.0
# %margin               39.77
# Name: 80634, dtype: object

# %%
data.drop(1500003,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3320\2113025807.py in <module>
# ----> 1 data.drop(1500003,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data.drop(1500005,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3320\481819177.py in <module>
# ----> 1 data.drop(1500005,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data.isnull().sum()
# Out:
# Region            1
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     5
# Total Cost        5
# Total Profit      5
# %margin           5
# dtype: int64
